# %% [markdown]
# <a href="https://colab.research.google.com/github/saritasaksu47-boop/python/blob/main/python_for_generative_AI_G3_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mysub= "python"

mysub
# Out:
# 'python'

# %%
print(mysub)
# Out:
# python

# %%
_mycity='solan'
print(_mycity)
# Out:
# solan

# %%
mysub1="gen. ai"
mysub1
# Out:
# 'gen. ai'

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#data type in python
#numeric
#integer-------absence of decimal point
#ex--------1,2,3
x=1
type(x)
# Out:
# int

# %%
#floating point number----presence of decimal point
#ex-------2.14,3.14
y=2.14
type(y)
# Out:
# float

# %%
#complex----combo of real and imaginary
z=4+9j
type(z)
# Out:
# complex

# %%
#string-----data in text
x="solan"

# %%
#none-----no data present
e = None
type(e)
# Out:
# NoneType

# %%
#boolgan------ to store true ND FALSE
a = True
type(a)
# Out:
# bool

# %%
#single quote string
my_sub='gen ai'
type(my_sub)
# Out:
# str

# %%
#double quote string
my__group=6
type(my__group)
# Out:
# int

# %%
#triple wala
my_age='''19'''
type(my_age)
# Out:
# str

# %%
my_sub="machine learning"
my_sub[0]
# Out:
# 'm'

# %%
#UPPER- THI METHOD CONVERTS STRING INTO UPPER CASE
my_sub="machine learning"
my_sub.upper()
# Out:
# 'MACHINE LEARNING'

# %%
#count()- this method counts particular characters in string.
my_sub="machine learning"
my_sub.count('a')
# Out:
# 2

# %%
#list - it is collection of item,

my_list = [88,98,9,87]
type(list)
# Out:
# type

# %%
print(my_list)
# Out:
# [88, 98, 9, 87]

# %%
mixed_list = [76,2.14,"apple","cake"]
type(mixed_list)
# Out:
# list

# %%
#indexing in list---location of item
my_list = []

# %%
#positive indexing/negative indexing
my_list = [78,90,76,54,67,78,87]
print(my_list[0])
print(my_list[3])
print(my_list[-2])
# Out:
# 78
# 54
# 78

# %%
# slicing in list - grab the data designated point is known as slicing.
my_list = [96,76,33,56]
#starting index is included- SI
#ending index is excluded - EI
my_list[0:3:2]
# Out:
# [96, 33]

# %%
my_list[0:4]
# Out:
# [96, 76, 33, 56]

# %%
my_list[0:]
# Out:
# [96, 76, 33, 56]

# %%
my_list[:3]
# Out:
# [96, 76, 33]

# %%
my_list[::-1]
# Out:
# [56, 33, 76, 96]

# %%
#function in list
print(my_list)
# Out:
# [96, 76, 33, 56]

# %%
min(my_list)
# Out:
# 33

# %%
max(my_list)
# Out:
# 96

# %%
sum(my_list)
# Out:
# 261

# %%
#sorted--this function arranges list in increasing/decreasing order

# %%
print (my_list)
# Out:
# [96, 76, 33, 56]

# %%
sorted(my_list)
# Out:
# [33, 56, 76, 96]

# %%
sorted(my_list,reverse= True)
# Out:
# [96, 76, 56, 33]

# %%
list1=[1,2,4]
list2=[8,9,7]
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 4, 8, 9, 7]

# %%
#list function does not changes the original list

# %%
#append()--this method add item at the end of the list
my_list.append(100)
print(my_list)
# Out:
# [96, 76, 33, 56, 100]

# %%
#extend()---this method merges lists

# %%
#sort()--this method use to arrange list into increasing order/decreasing order.
my_list=[12,23,9,8,17]
my_list.sort()
my_list
# Out:
# [8, 9, 12, 17, 23]

# %%
my_list.sort(reverse=True)
my_list
# Out:
# [23, 17, 12, 9, 8]

# %%
#pop()--this method remove item from the list and take index as argument
list1=[9,8,78,67,13]
list1.pop(2)
# Out:
# 78

# %%
#remove()-it also remove an item from the list but it takes item as an argument
my_list=[89,67,54,34]
my_list.remove(89)

# %%
my_list
# Out:
# [67, 54, 34]

# %%
#dictionary--it is collection of key value pair,
# key and value separated by colon.
#the combination of key and value is known as item.every item seoarated by comma,all item are enclosed by curly braces
#my_dict={"hp":"shimla":"up":"luck"}

# %%
#dicitionary
my_dict={"hp":"shimla","up":"lucknow"}
print(my_dict)
# Out:
# {'hp': 'shimla', 'up': 'lucknow'}

# %%
print(my_dict["hp"])
# Out:
# shimla

# %%
print(my_dict["up"])
# Out:
# lucknow

# %%
#keys()--this method returns keys of dictionary
list(my_dict.keys())
# Out:
# ['hp', 'up']

# %%
#values()--this method find value of the dictionary
list(my_dict.values())
# Out:
# ['shimla', 'lucknow']

# %%
#items()--this method returns item of the dictionary
list(my_dict.items())
# Out:
# [('hp', 'shimla'), ('up', 'lucknow')]

# %%
#get()--the method returns the value of the dictionary and take keys as arguments
my_dict.get("hp")
# Out:
# 'shimla'

# %%
#update()---this method upadtes the dict.and take dict. as an argument
my_dict.update({"name":"target"})
print(my_dict)
# Out:
# {'hp': 'shimla', 'up': 'lucknow', 'name': 'target'}

# %%
#conditional statement
#if
#elif
#else
age= int(input ("enter your age "))
if age>60 :
  print("you're too old to marry")
elif age<18 :
  print("youre too young to marry")
else :
  print("you will find a perfect match for you")
# Out:
# enter your age 23
# you will find a perfect match for you

# %%
my_sub="python"
print(my_sub[0])
# Out:
# p

# %%
my_sub="python"
for i in my_sub:
 print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
my_sub="saksham sharma"
for i in my_sub:
  print(i)
# Out:
# s
# a
# k
# s
# h
# a
# m
#
# s
# h
# a
# r
# m
# a

# %%
#range (SP,EP,SS)
#SP--
#EP--ENDING POINT
#SS--STOP SIZE,BY DEFAULT IT IS OVER

# %%
#range(0,6,2) #range (0,6)
#0            #0
#1

# %%
for i in range(6) :
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#list
my_list=[1,2,3,45,]
for i in my_list:
  print(i)
# Out:
# 1
# 2
# 3
# 45

# %%
#loop control statement
#break--this statement break the loop
i = 0
while i<5:
  i+=1
  if i==3:
    break
  print(i)
# Out:
# 1
# 2

# %%
#while loop
i=0
while i>5:
  print(i)
i+=1

# %%
#continue--this statement skip the current iteration
i = 0
while i<5:
  i+=1
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
#keyword argument
def interest(p,r,t):
  i = (p*r*t)/100
  return i

# %%
print(interest(r=10,p=1000,t=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2041909726.py in <cell line: 0>()
# ----> 1 print(interest(r=10,p=1000,t=2))
#
# NameError: name 'interest' is not defined

# %%
test(2,3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3803369495.py in <cell line: 0>()
# ----> 1 test(2,3,4,5,6)
#
# NameError: name 'test' is not defined

# %%
def sum_number(*args):
  sum = 0
  for num in args:
    sum+=num
    return sum

# %%
sum_number(1,2,3,4,5,6,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3623288006.py in <cell line: 0>()
# ----> 1 sum_number(1,2,3,4,5,6,)
#
# NameError: name 'sum_number' is not defined

# %%
def sum_number(*args):
  sum = 0
  for num in args:
    sum+=num
  return sum

# %%
sum_number(1,2,3,4,5,6,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3623288006.py in <cell line: 0>()
# ----> 1 sum_number(1,2,3,4,5,6,)
#
# NameError: name 'sum_number' is not defined

# %%
def sum_number(*args):
  sum = 0
  for num in args:
    sum+=num
  return sum

# %%
sum_number(1,2,3,4,5,6,)
# Out:
# 21

# %%
def sum_number(*args):
  sum = 0
  for num in args:
    sum+=num
  return sum

# %%
sum_number(1,2,3,4,5,6,)
# Out:
# 21

# %%
#numpy -- numerical python
#it is used for mathematics
#data structure of numpie is multidimensional
#data structure  of numpy is multidimensional array

# %%
import numpy as np

# %%
#one dimensional array
oned_array = np.array([1,2,3,4])
print(oned_array)
# Out:
# [1 2 3 4]

# %%
#two dimensional array
twod_array = np.array([[1,2,3],[4,5,6]])
print (twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#size -- represent number of item to the array
print()

# %%
#indexing

# %%
#vv

# %%
import numpy as np
my_array= np.array([1,2,3,4])
print(my_array)
# Out:
# [1 2 3 4]

# %%
power_array = np.power(my_array, 2)
print(power_array)
# Out:
# [ 1  4  9 16]

# %%
log_array = np.log(my_array)
print(log_array)
# Out:
# [0.         0.69314718 1.09861229 1.38629436]

# %%
log2_array = np.log2(my_array)
print(log2_array)
# Out:
# [0.        1.        1.5849625 2.       ]

# %%
log10_array = np.log10(my_array)
print(log10_array)
# Out:
# [0.         0.30103    0.47712125 0.60205999]

# %%
exp_array = np.exp(my_array)
print(exp_array)
# Out:
# [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
import matplotlib.pyplot as plt

# %%
Def add():
a = int(input("enter first number:"))
b

# %%
Print (area_perimeter(10,

# %%
#data structure- it is a fundamental for any programming lang. around which programme is built.
type of data structure-
mutuable dt - changeable after being built.
iske bhi types -
list
dictionary
set.
# Out:
#   File "/tmp/ipython-input-1392739301.py", line 2
#     type of data structure-
#             ^
# SyntaxError: invalid syntax

# %%
slicing in string-
grab the data upto desiganted point
my_sub="machine learning"
my_sub(SI :L )

# %% [markdown]
# immutable DT
# not changeable after being built.
# types
# string
# couple
# number

# %%
#range
for i in range(0,6,1):
print(i)

# %%
len(my_sub) this function defines the length of the string.

# %%
from transformers import pipeline
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
text -"""The global shift toward renewable energy is accelerating, driven by concerns over climate change and energy security. Solar and wind power installations have reached record levels worldwide."""
summary = summarizer(text, max_length=30, min_length=10, do_sample=False)
print(summary[0])
# Out:
# Device set to use cpu
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2760619111.py in <cell line: 0>()
#       1 from transformers import pipeline
#       2 summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# ----> 3 text -"""The global shift toward renewable energy is accelerating, driven by concerns over climate change and energy security. Solar and wind power installations have reached record levels worldwide."""
#       4 summary = summarizer(text, max_length=30, min_length=10, do_sample=False)
#       5 print(summary[0])
#
# NameError: name 'text' is not defined

# %%
pract

# %% [markdown]
# STRING-sequence of character or icon.it is enclosed by ",' or"'.it is immutable type data structure.it could be either word,sentence,paragraph or an entire encyclopedia.
